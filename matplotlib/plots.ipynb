# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([10,100,50,100,100,50,10,10])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
y
# Out:
# array([ 10, 100,  50, 100, 100,  50,  10,  10])

# %% [markdown]
# **types of plots**

# %%
#line plot
plt.plot(x,y)

# %%
# bar chart 
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
# scatter graph
plt.scatter(x,y)
